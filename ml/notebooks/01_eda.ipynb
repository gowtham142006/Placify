# %% [markdown]
# ## Display first 5 Rows

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(
    "../data/student_placement_prediction_dataset_2026-selected-columns.csv"
)

df.head()
# Out:
#    age  gender  cgpa branch college_tier  internships_count  projects_count  \
# 0   24    Male  7.53     IT       Tier 2                  4               6
# 1   21    Male  7.92    CSE       Tier 2                  1               3
# 2   22  Female  8.60    EEE       Tier 1                  0               1
# 3   24    Male  6.68    CSE       Tier 1                  0               2
# 4   20  Female  8.43     IT       Tier 3                  1               4
#
#    certifications_count  coding_skill_score  aptitude_score  \
# 0                     1           99.238568       81.707722
# 1                     6           80.966123       63.116715
# 2                     1           49.177184       48.658753
# 3                     2           79.359084       66.376653
# 4                     3           65.018573       61.274985
#
#    communication_skill_score  logical_reasoning_score  mock_interview_score  \
# 0                  57.707166                59.070073             72.647009
# 1                  59.197085                78.976419             61.699110
# 2                  92.104885                80.603331             87.396911
# 3                  83.411798                64.187246             58.401069
# 4                  88.956331                56.163678             74.489201
#
#    backlogs placement_status
# 0         2       Not Placed
# 1         1       Not Placed
# 2         0           Placed
# 3         1       Not Placed
# 4         1           Placed

# %% [markdown]
# ## Columns and Data Type

# %%
print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Types:")
print(df.dtypes)
# Out:
# Dataset Shape: (100000, 15)
#
# Column Names:
# ['age', 'gender', 'cgpa', 'branch', 'college_tier', 'internships_count', 'projects_count', 'certifications_count', 'coding_skill_score', 'aptitude_score', 'communication_skill_score', 'logical_reasoning_score', 'mock_interview_score', 'backlogs', 'placement_status']
#
# Data Types:
# age                            int64
# gender                           str
# cgpa                         float64
# branch                           str
# college_tier                     str
# internships_count              int64
# projects_count                 int64
# certifications_count           int64
# coding_skill_score           float64
# aptitude_score               float64
# communication_skill_score    float64
# logical_reasoning_score      float64
# mock_interview_score         float64
# backlogs                       int64
# placement_status                 str
# dtype: object

# %% [markdown]
# ## missing values

# %%
print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# age                          0
# gender                       0
# cgpa                         0
# branch                       0
# college_tier                 0
# internships_count            0
# projects_count               0
# certifications_count         0
# coding_skill_score           0
# aptitude_score               0
# communication_skill_score    0
# logical_reasoning_score      0
# mock_interview_score         0
# backlogs                     0
# placement_status             0
# dtype: int64
#
# Duplicate Rows:
# 0

# %% [markdown]
# ## Placement Distribution

# %%
target_counts = df["placement_status"].value_counts()

print("Placement Status Counts:")
print(target_counts)

print("\nPlacement Status Percentage:")
print(df["placement_status"].value_counts(normalize=True) * 100)
# Out:
# Placement Status Counts:
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64
#
# Placement Status Percentage:
# placement_status
# Placed        54.459
# Not Placed    45.541
# Name: proportion, dtype: float64

# %%
target_counts.plot(
    kind="bar",
    title="Placement Status Distribution"
)

plt.xlabel("Placement Status")
plt.ylabel("Number of Students")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### CGPA statistics by placement

# %%
df.groupby("placement_status")["cgpa"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                       mean  median  min   max
# placement_status
# Not Placed        7.483789    7.49  4.5  10.0
# Placed            7.507846    7.51  4.5  10.0

# %% [markdown]
# ### CGPA distribution

# %%
df.boxplot(
    column="cgpa",
    by="placement_status"
)

plt.title("CGPA Distribution by Placement Status")
plt.suptitle("")
plt.xlabel("Placement Status")
plt.ylabel("CGPA")
plt.show()

# %% [markdown]
# ## Internships, Projects & Certifications

# %% [markdown]
# ### Internships

# %%
df.groupby("placement_status")["internships_count"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                       mean  median  min  max
# placement_status
# Not Placed        1.417163     1.0    0    8
# Placed            1.573367     1.0    0    8

# %%
df.groupby("internships_count")["placement_status"].value_counts(normalize=True).unstack() * 100
# Out:
# placement_status   Not Placed     Placed
# internships_count
# 0                   49.682475  50.317525
# 1                   46.297621  53.702379
# 2                   44.600247  55.399753
# 3                   42.048796  57.951204
# 4                   40.055782  59.944218
# 5                   34.631148  65.368852
# 6                   26.744186  73.255814
# 7                   27.027027  72.972973
# 8                   27.272727  72.727273

# %% [markdown]
# ### Projects

# %%
df.groupby("placement_status")["projects_count"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                       mean  median  min  max
# placement_status
# Not Placed        2.886410     3.0    0   12
# Placed            3.098404     3.0    0   13

# %%
df.groupby("projects_count")["placement_status"].value_counts(normalize=True).unstack() * 100
# Out:
# placement_status  Not Placed      Placed
# projects_count
# 0                  50.909458   49.090542
# 1                  48.760054   51.239946
# 2                  47.212645   52.787355
# 3                  45.697131   54.302869
# 4                  44.192517   55.807483
# 5                  41.419126   58.580874
# 6                  40.794893   59.205107
# 7                  40.097475   59.902525
# 8                  34.451613   65.548387
# 9                  28.825623   71.174377
# 10                 27.160494   72.839506
# 11                 28.125000   71.875000
# 12                 20.000000   80.000000
# 13                       NaN  100.000000

# %% [markdown]
# ### Certifications

# %%
df.groupby("placement_status")["certifications_count"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                       mean  median  min  max
# placement_status
# Not Placed        2.011045     2.0    0   10
# Placed            2.000220     2.0    0   11

# %%
df.groupby("certifications_count")["placement_status"].value_counts(normalize=True).unstack() * 100
# Out:
# placement_status      Not Placed      Placed
# certifications_count
# 0                      44.974370   55.025630
# 1                      45.426100   54.573900
# 2                      45.830845   54.169155
# 3                      45.539751   54.460249
# 4                      45.643793   54.356207
# 5                      45.718901   54.281099
# 6                      47.155812   52.844188
# 7                      45.639535   54.360465
# 8                      35.616438   64.383562
# 9                      50.000000   50.000000
# 10                    100.000000         NaN
# 11                           NaN  100.000000

# %% [markdown]
# ## Skill Analysis

# %% [markdown]
# ### Coding Skill

# %%
df.groupby("placement_status")["coding_skill_score"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                        mean     median   min    max
# placement_status
# Not Placed        69.009449  69.149666  20.0  100.0
# Placed            70.507598  70.732405  20.0  100.0

# %%
df.groupby("placement_status")["coding_skill_score"].describe()
# Out:
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  69.009449  14.742008  20.0  58.986744  69.149666
# Placed            54459.0  70.507598  14.620091  20.0  60.530369  70.732405
#
#                         75%    max
# placement_status
# Not Placed        79.162010  100.0
# Placed            80.759221  100.0

# %%
df.boxplot(
    column="coding_skill_score",
    by="placement_status"
)

plt.title("Coding Skill Score by Placement Status")
plt.suptitle("")
plt.xlabel("Placement Status")
plt.ylabel("Coding Skill Score")
plt.show()

# %% [markdown]
# ### aptitude_score

# %%
df.groupby("placement_status")["aptitude_score"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                        mean     median   min    max
# placement_status
# Not Placed        64.473703  64.416237  20.0  100.0
# Placed            65.418276  65.469800  20.0  100.0

# %%
df.groupby("placement_status")["aptitude_score"].describe()
# Out:
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  64.473703  14.835838  20.0  54.378756  64.416237
# Placed            54459.0  65.418276  14.837443  20.0  55.323007  65.469800
#
#                         75%    max
# placement_status
# Not Placed        74.594539  100.0
# Placed            75.439412  100.0

# %%
df.boxplot(
    column="aptitude_score",
    by="placement_status"
)

plt.title("aptitude_score by Placement Status")
plt.suptitle("")
plt.xlabel("Placement Status")
plt.ylabel("aptitude_score")
plt.show()

# %% [markdown]
# ### communication_skill_score

# %%
df.groupby("placement_status")["communication_skill_score"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                        mean     median   min    max
# placement_status
# Not Placed        67.472542  67.448215  20.0  100.0
# Placed            68.368999  68.440795  20.0  100.0

# %%
df.groupby("placement_status")["communication_skill_score"].describe()
# Out:
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  67.472542  13.819202  20.0  58.135824  67.448215
# Placed            54459.0  68.368999  13.856462  20.0  58.981559  68.440795
#
#                         75%    max
# placement_status
# Not Placed        77.007480  100.0
# Placed            77.926139  100.0

# %%
df.boxplot(
    column="communication_skill_score",
    by="placement_status"
)

plt.title("Ccommunication_skill_score by Placement Status")
plt.suptitle("")
plt.xlabel("Placement Status")
plt.ylabel("communication_skill_score")
plt.show()

# %% [markdown]
# ### logical_reasoning_score

# %%
df.groupby("placement_status")["logical_reasoning_score"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                        mean     median   min    max
# placement_status
# Not Placed        65.342630  65.414057  20.0  100.0
# Placed            66.424298  66.451542  20.0  100.0

# %%
df.groupby("placement_status")["logical_reasoning_score"].describe()
# Out:
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  65.342630  14.881248  20.0  55.280831  65.414057
# Placed            54459.0  66.424298  14.763197  20.0  56.417580  66.451542
#
#                         75%    max
# placement_status
# Not Placed        75.528112  100.0
# Placed            76.610590  100.0

# %%
df.boxplot(
    column="logical_reasoning_score",
    by="placement_status"
)

plt.title("logical_reasoning_score by Placement Status")
plt.suptitle("")
plt.xlabel("Placement Status")
plt.ylabel("logical_reasoning_score")
plt.show()

# %% [markdown]
# ### mock_interview_score

# %%
df.groupby("placement_status")["mock_interview_score"].agg(
    ["mean", "median", "min", "max"]
)
# Out:
#                        mean     median   min    max
# placement_status
# Not Placed        69.388182  69.394943  20.0  100.0
# Placed            70.492185  70.535418  20.0  100.0

# %%
df.groupby("placement_status")["mock_interview_score"].describe()
# Out:
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  69.388182  11.931625  20.0  61.336269  69.394943
# Placed            54459.0  70.492185  11.918812  20.0  62.475740  70.535418
#
#                         75%    max
# placement_status
# Not Placed        77.500865  100.0
# Placed            78.599476  100.0

# %%
df.boxplot(
    column="mock_interview_score",
    by="placement_status"
)

plt.title("mock_interview_score by Placement Status")
plt.suptitle("")
plt.xlabel("Placement Status")
plt.ylabel("mock_interview_score")
plt.show()

# %% [markdown]
# ### Gender vs Placement Status

# %%
gender_placement = pd.crosstab(
    df["gender"],
    df["placement_status"],
    normalize="index"
) * 100

gender_placement
# Out:
# placement_status  Not Placed     Placed
# gender
# Female             45.616932  54.383068
# Male               45.490438  54.509562

# %%
gender_placement.plot(
    kind="bar",
    stacked=True
)

plt.title("Placement Status by Gender")
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.xticks(rotation=0)
plt.legend(title="Placement Status")
plt.show()

# %% [markdown]
# ### Branch vs Placement Status

# %%
branch_placement = pd.crosstab(
    df["branch"],
    df["placement_status"],
    normalize="index"
) * 100

branch_placement
# Out:
# placement_status  Not Placed     Placed
# branch
# CSE                45.355850  54.644150
# Civil              44.825866  55.174134
# ECE                45.894822  54.105178
# EEE                45.681439  54.318561
# IT                 45.697285  54.302715
# Mechanical         45.916443  54.083557

# %%
branch_placement.plot(
    kind="bar",
    stacked=True
)

plt.title("Placement Status by Branch")
plt.xlabel("Branch")
plt.ylabel("Percentage")
plt.xticks(rotation=45)
plt.legend(title="Placement Status")
plt.show()

# %% [markdown]
# ### College Tier vs Placement Status

# %%
tier_placement = pd.crosstab(
    df["college_tier"],
    df["placement_status"],
    normalize="index"
) * 100

tier_placement
# Out:
# placement_status  Not Placed     Placed
# college_tier
# Tier 1             45.498735  54.501265
# Tier 2             45.715144  54.284856
# Tier 3             45.278410  54.721590

# %%
tier_placement.plot(
    kind="bar",
    stacked=True
)

plt.title("Placement Status by College Tier")
plt.xlabel("College Tier")
plt.ylabel("Percentage")
plt.xticks(rotation=0)
plt.legend(title="Placement Status")
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
# Select numerical columns
numeric_columns = [
    "age",
    "cgpa",
    "internships_count",
    "projects_count",
    "certifications_count",
    "coding_skill_score",
    "aptitude_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "mock_interview_score",
    "backlogs"
]

correlation = df[numeric_columns].corr()

correlation
# Out:
#                                 age      cgpa  internships_count  \
# age                        1.000000  0.004160           0.002791
# cgpa                       0.004160  1.000000           0.004149
# internships_count          0.002791  0.004149           1.000000
# projects_count            -0.002062  0.004069           0.000625
# certifications_count      -0.000056 -0.001269          -0.002689
# coding_skill_score         0.000573  0.004129          -0.002755
# aptitude_score            -0.000839 -0.003143           0.000561
# communication_skill_score -0.000353  0.004439          -0.001777
# logical_reasoning_score    0.001009 -0.002373          -0.000275
# mock_interview_score      -0.004293 -0.000787           0.004463
# backlogs                  -0.001162 -0.001086           0.003531
#
#                            projects_count  certifications_count  \
# age                             -0.002062             -0.000056
# cgpa                             0.004069             -0.001269
# internships_count                0.000625             -0.002689
# projects_count                   1.000000              0.001765
# certifications_count             0.001765              1.000000
# coding_skill_score              -0.003686             -0.001757
# aptitude_score                  -0.000822             -0.000309
# communication_skill_score       -0.002146              0.001655
# logical_reasoning_score         -0.005138             -0.000596
# mock_interview_score            -0.003240              0.003777
# backlogs                         0.001658              0.002230
#
#                            coding_skill_score  aptitude_score  \
# age                                  0.000573       -0.000839
# cgpa                                 0.004129       -0.003143
# internships_count                   -0.002755        0.000561
# projects_count                      -0.003686       -0.000822
# certifications_count                -0.001757       -0.000309
# coding_skill_score                   1.000000       -0.000591
# aptitude_score                      -0.000591        1.000000
# communication_skill_score           -0.000151       -0.002720
# logical_reasoning_score              0.001806        0.000469
# mock_interview_score                -0.005713       -0.003278
# backlogs                            -0.003305        0.001982
#
#                            communication_skill_score  logical_reasoning_score  \
# age                                        -0.000353                 0.001009
# cgpa                                        0.004439                -0.002373
# internships_count                          -0.001777                -0.000275
# projects_count                             -0.002146                -0.005138
# certifications_count                        0.001655                -0.000596
# coding_skill_score                         -0.000151                 0.001806
# aptitude_score                             -0.002720                 0.000469
# communication_skill_score                   1.000000                 0.003984
# logical_reasoning_score                     0.003984                 1.000000
# mock_interview_score                        0.000714                 0.004122
# backlogs                                   -0.000546                -0.000679
#
#                            mock_interview_score  backlogs
# age                                   -0.004293 -0.001162
# cgpa                                  -0.000787 -0.001086
# internships_count                      0.004463  0.003531
# projects_count                        -0.003240  0.001658
# certifications_count                   0.003777  0.002230
# coding_skill_score                    -0.005713 -0.003305
# aptitude_score                        -0.003278  0.001982
# communication_skill_score              0.000714 -0.000546
# logical_reasoning_score                0.004122 -0.000679
# mock_interview_score                   1.000000 -0.003349
# backlogs                              -0.003349  1.000000

# %%
# Correlation with placement status

df["placement_status_numeric"] = (
    df["placement_status"]
    .map({"Not Placed": 0, "Placed": 1})
)

target_correlation = (
    df[numeric_columns + ["placement_status_numeric"]]
    .corr()["placement_status_numeric"]
    .sort_values(ascending=False)
)

target_correlation
# Out:
# placement_status_numeric     1.000000
# internships_count            0.063489
# projects_count               0.060964
# coding_skill_score           0.050773
# mock_interview_score         0.046058
# logical_reasoning_score      0.036332
# communication_skill_score    0.032242
# aptitude_score               0.031690
# cgpa                         0.012067
# age                          0.000858
# certifications_count        -0.003806
# backlogs                    -0.082404
# Name: placement_status_numeric, dtype: float64

# %%
# Check placement status distribution
print("Placement Status Distribution:")
print(df["placement_status"].value_counts())

print("\nPlacement Status Percentage:")
print(df["placement_status"].value_counts(normalize=True) * 100)
# Out:
# Placement Status Distribution:
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64
#
# Placement Status Percentage:
# placement_status
# Placed        54.459
# Not Placed    45.541
# Name: proportion, dtype: float64

# %%
# Compare average feature values between placed and not placed students

comparison = df.groupby("placement_status")[numeric_columns].mean().T

comparison
# Out:
# placement_status           Not Placed     Placed
# age                         21.003865  21.007308
# cgpa                         7.483789   7.507846
# internships_count            1.417163   1.573367
# projects_count               2.886410   3.098404
# certifications_count         2.011045   2.000220
# coding_skill_score          69.009449  70.507598
# aptitude_score              64.473703  65.418276
# communication_skill_score   67.472542  68.368999
# logical_reasoning_score     65.342630  66.424298
# mock_interview_score        69.388182  70.492185
# backlogs                     0.561428   0.444206

# %%
# Difference between placed and not placed students

difference = (
    df.groupby("placement_status")[numeric_columns]
    .mean()
    .T
)

difference["difference"] = (
    difference.iloc[:, 1] - difference.iloc[:, 0]
)

difference.sort_values("difference", ascending=False)
# Out:
# placement_status           Not Placed     Placed  difference
# coding_skill_score          69.009449  70.507598    1.498149
# mock_interview_score        69.388182  70.492185    1.104004
# logical_reasoning_score     65.342630  66.424298    1.081668
# aptitude_score              64.473703  65.418276    0.944573
# communication_skill_score   67.472542  68.368999    0.896457
# projects_count               2.886410   3.098404    0.211994
# internships_count            1.417163   1.573367    0.156205
# cgpa                         7.483789   7.507846    0.024058
# age                         21.003865  21.007308    0.003444
# certifications_count         2.011045   2.000220   -0.010825
# backlogs                     0.561428   0.444206   -0.117222

# %%
# Check whether placement status is actually connected to the features

for column in numeric_columns:
    print(f"\n{column}")
    print(df.groupby("placement_status")[column].describe())
# Out:
# age
#                     count       mean       std   min   25%   50%   75%   max
# placement_status
# Not Placed        45541.0  21.003865  2.002202  18.0  19.0  21.0  23.0  24.0
# Placed            54459.0  21.007308  1.997368  18.0  19.0  21.0  23.0  24.0
#
# cgpa
#                     count      mean       std  min   25%   50%   75%   max
# placement_status
# Not Placed        45541.0  7.483789  0.993122  4.5  6.81  7.49  8.17  10.0
# Placed            54459.0  7.507846  0.992469  4.5  6.83  7.51  8.18  10.0
#
# internships_count
#                     count      mean       std  min  25%  50%  75%  max
# placement_status
# Not Placed        45541.0  1.417163  1.182647  0.0  1.0  1.0  2.0  8.0
# Placed            54459.0  1.573367  1.255416  0.0  1.0  1.0  2.0  8.0
#
# projects_count
#                     count      mean       std  min  25%  50%  75%   max
# placement_status
# Not Placed        45541.0  2.886410  1.687065  0.0  2.0  3.0  4.0  12.0
# Placed            54459.0  3.098404  1.762495  0.0  2.0  3.0  4.0  13.0
#
# certifications_count
#                     count      mean       std  min  25%  50%  75%   max
# placement_status
# Not Placed        45541.0  2.011045  1.415653  0.0  1.0  2.0  3.0  10.0
# Placed            54459.0  2.000220  1.417300  0.0  1.0  2.0  3.0  11.0
#
# coding_skill_score
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  69.009449  14.742008  20.0  58.986744  69.149666
# Placed            54459.0  70.507598  14.620091  20.0  60.530369  70.732405
#
#                         75%    max
# placement_status
# Not Placed        79.162010  100.0
# Placed            80.759221  100.0
#
# aptitude_score
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  64.473703  14.835838  20.0  54.378756  64.416237
# Placed            54459.0  65.418276  14.837443  20.0  55.323007  65.469800
#
#                         75%    max
# placement_status
# Not Placed        74.594539  100.0
# Placed            75.439412  100.0
#
# communication_skill_score
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  67.472542  13.819202  20.0  58.135824  67.448215
# Placed            54459.0  68.368999  13.856462  20.0  58.981559  68.440795
#
#                         75%    max
# placement_status
# Not Placed        77.007480  100.0
# Placed            77.926139  100.0
#
# logical_reasoning_score
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  65.342630  14.881248  20.0  55.280831  65.414057
# Placed            54459.0  66.424298  14.763197  20.0  56.417580  66.451542
#
#                         75%    max
# placement_status
# Not Placed        75.528112  100.0
# Placed            76.610590  100.0
#
# mock_interview_score
#                     count       mean        std   min        25%        50%  \
# placement_status
# Not Placed        45541.0  69.388182  11.931625  20.0  61.336269  69.394943
# Placed            54459.0  70.492185  11.918812  20.0  62.475740  70.535418
#
#                         75%    max
# placement_status
# Not Placed        77.500865  100.0
# Placed            78.599476  100.0
#
# backlogs
#                     count      mean       std  min  25%  50%  75%  max
# placement_status
# Not Placed        45541.0  0.561428  0.752355  0.0  0.0  0.0  1.0  6.0
# Placed            54459.0  0.444206  0.664814  0.0  0.0  0.0  1.0  5.0

# %% [markdown]
# ## Baseline ML experiment using Logistic Regression

# %%
# Baseline ML experiment

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report
)

# Features and target
X = df.drop(
    columns=[
        "placement_status",
        "placement_status_numeric"
    ],
    errors="ignore"
)
y = df["placement_status"].map({
    "Not Placed": 0,
    "Placed": 1
})

# Identify columns
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_features = X.select_dtypes(include=["object", "category"]).columns.tolist()

print("Numeric features:")
print(numeric_features)

print("\nCategorical features:")
print(categorical_features)

# Preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            Pipeline([
                ("imputer", SimpleImputer(strategy="median")),
                ("scaler", StandardScaler())
            ]),
            numeric_features
        ),
        (
            "cat",
            Pipeline([
                ("imputer", SimpleImputer(strategy="most_frequent")),
                ("onehot", OneHotEncoder(handle_unknown="ignore"))
            ]),
            categorical_features
        )
    ]
)

# Model
model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", LogisticRegression(max_iter=1000))
])

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# Train
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# Evaluation
print("\n===== Logistic Regression Results =====")

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))
print("ROC-AUC  :", roc_auc_score(y_test, y_prob))

print("\nClassification Report:")
print(classification_report(
    y_test,
    y_pred,
    target_names=["Not Placed", "Placed"]
))
# Out:
# Numeric features:
# ['age', 'cgpa', 'internships_count', 'projects_count', 'certifications_count', 'coding_skill_score', 'aptitude_score', 'communication_skill_score', 'logical_reasoning_score', 'mock_interview_score', 'backlogs']
#
# Categorical features:
# ['gender', 'branch', 'college_tier']
# C:\Users\gowth\AppData\Local\Temp\ipykernel_11860\69484528.py:33: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_features = X.select_dtypes(include=["object", "category"]).columns.tolist()
# ===== Logistic Regression Results =====
# Accuracy : 0.56845
# Precision: 0.5768995306441739
# Recall   : 0.7786448769739258
# F1 Score : 0.6627593482592896
# ROC-AUC  : 0.5838032926302738
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Not Placed       0.55      0.32      0.40      9108
#       Placed       0.58      0.78      0.66     10892
#
#     accuracy                           0.57     20000
#    macro avg       0.56      0.55      0.53     20000
# weighted avg       0.56      0.57      0.54     20000

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (80000, 14)
# X_test: (20000, 14)
# y_train: (80000,)
# y_test: (20000,)

# %% [markdown]
# ## Random Forest experiment.

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(
        n_estimators=100,
        random_state=42,
        n_jobs=-1
    ))
])

# Train
rf_model.fit(X_train, y_train)

# Predictions
rf_pred = rf_model.predict(X_test)
rf_prob = rf_model.predict_proba(X_test)[:, 1]

# Evaluation
print("===== Random Forest Results =====")

print("Accuracy :", accuracy_score(y_test, rf_pred))
print("Precision:", precision_score(y_test, rf_pred))
print("Recall   :", recall_score(y_test, rf_pred))
print("F1 Score :", f1_score(y_test, rf_pred))
print("ROC-AUC  :", roc_auc_score(y_test, rf_prob))

print("\nClassification Report:")
print(classification_report(
    y_test,
    rf_pred,
    target_names=["Not Placed", "Placed"]
))
# Out:
# ===== Random Forest Results =====
# Accuracy : 0.5518
# Precision: 0.572296385180741
# Recall   : 0.7006059493206023
# F1 Score : 0.6299843143729877
# ROC-AUC  : 0.553856199390317
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Not Placed       0.51      0.37      0.43      9108
#       Placed       0.57      0.70      0.63     10892
#
#     accuracy                           0.55     20000
#    macro avg       0.54      0.54      0.53     20000
# weighted avg       0.54      0.55      0.54     20000

# %% [markdown]
# ## Gradient Boosting Experiment

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", GradientBoostingClassifier(
        learning_rate=0.05,
        n_estimators=150,
        subsample=0.8,
        random_state=42
    ))
])

# Train
gb_model.fit(X_train, y_train)

# Predictions
gb_pred = gb_model.predict(X_test)
gb_prob = gb_model.predict_proba(X_test)[:, 1]

# Evaluation
print("===== Gradient Boosting Results =====")

print("Accuracy :", accuracy_score(y_test, gb_pred))
print("Precision:", precision_score(y_test, gb_pred))
print("Recall   :", recall_score(y_test, gb_pred))
print("F1 Score :", f1_score(y_test, gb_pred))
print("ROC-AUC  :", roc_auc_score(y_test, gb_prob))

print("\nClassification Report:")
print(classification_report(
    y_test,
    gb_pred,
    target_names=["Not Placed", "Placed"]
))
# Out:
# ===== Gradient Boosting Results =====
# Accuracy : 0.5669
# Precision: 0.5726005990363329
# Recall   : 0.8073815644509732
# F1 Score : 0.6700190476190476
# ROC-AUC  : 0.5801339721683133
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Not Placed       0.55      0.28      0.37      9108
#       Placed       0.57      0.81      0.67     10892
#
#     accuracy                           0.57     20000
#    macro avg       0.56      0.54      0.52     20000
# weighted avg       0.56      0.57      0.53     20000

# %% [markdown]
# ## Model Comparison Table

# %%
import pandas as pd

model_results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest",
        "Gradient Boosting"
    ],
    "Accuracy": [
        accuracy_score(y_test, y_pred),
        accuracy_score(y_test, rf_pred),
        accuracy_score(y_test, gb_pred)
    ],
    "Precision": [
        precision_score(y_test, y_pred),
        precision_score(y_test, rf_pred),
        precision_score(y_test, gb_pred)
    ],
    "Recall": [
        recall_score(y_test, y_pred),
        recall_score(y_test, rf_pred),
        recall_score(y_test, gb_pred)
    ],
    "F1 Score": [
        f1_score(y_test, y_pred),
        f1_score(y_test, rf_pred),
        f1_score(y_test, gb_pred)
    ],
    "ROC-AUC": [
        roc_auc_score(y_test, y_prob),
        roc_auc_score(y_test, rf_prob),
        roc_auc_score(y_test, gb_prob)
    ]
})

model_results
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0  Logistic Regression   0.56845   0.576900  0.778645  0.662759  0.583803
# 1        Random Forest   0.55180   0.572296  0.700606  0.629984  0.553856
# 2    Gradient Boosting   0.56690   0.572601  0.807382  0.670019  0.580134

# %% [markdown]
# ### Check feature correlations

# %%
# Select only numerical columns
numeric_df = df.select_dtypes(include=["int64", "float64"])

# Correlation with placement status
correlation = numeric_df.corr()["placement_status_numeric"].sort_values(
    ascending=False
)

print(correlation)
# Out:
# placement_status_numeric     1.000000
# internships_count            0.063489
# projects_count               0.060964
# coding_skill_score           0.050773
# mock_interview_score         0.046058
# logical_reasoning_score      0.036332
# communication_skill_score    0.032242
# aptitude_score               0.031690
# cgpa                         0.012067
# age                          0.000858
# certifications_count        -0.003806
# backlogs                    -0.082404
# Name: placement_status_numeric, dtype: float64

# %%
categorical_features = [
    "gender",
    "branch",
    "college_tier"
]

for feature in categorical_features:
    print(f"\n===== {feature.upper()} =====")

    result = pd.crosstab(
        df[feature],
        df["placement_status"],
        normalize="index"
    ) * 100

    print(result.round(2))
# Out:
# ===== GENDER =====
# placement_status  Not Placed  Placed
# gender
# Female                 45.62   54.38
# Male                   45.49   54.51
#
# ===== BRANCH =====
# placement_status  Not Placed  Placed
# branch
# CSE                    45.36   54.64
# Civil                  44.83   55.17
# ECE                    45.89   54.11
# EEE                    45.68   54.32
# IT                     45.70   54.30
# Mechanical             45.92   54.08
#
# ===== COLLEGE_TIER =====
# placement_status  Not Placed  Placed
# college_tier
# Tier 1                 45.50   54.50
# Tier 2                 45.72   54.28
# Tier 3                 45.28   54.72

# %% [markdown]
# ### Check categorical features against placement status

# %%
for column in categorical_features:
    print(f"\n===== {column} =====")
    print(pd.crosstab(
        df[column],
        df["placement_status"],
        normalize="index"
    ).round(4))
# Out:
# ===== gender =====
# placement_status  Not Placed  Placed
# gender
# Female                0.4562  0.5438
# Male                  0.4549  0.5451
#
# ===== branch =====
# placement_status  Not Placed  Placed
# branch
# CSE                   0.4536  0.5464
# Civil                 0.4483  0.5517
# ECE                   0.4589  0.5411
# EEE                   0.4568  0.5432
# IT                    0.4570  0.5430
# Mechanical            0.4592  0.5408
#
# ===== college_tier =====
# placement_status  Not Placed  Placed
# college_tier
# Tier 1                0.4550  0.5450
# Tier 2                0.4572  0.5428
# Tier 3                0.4528  0.5472

# %% [markdown]
# ### Measure how strongly each individual feature separates placement status

# %%
# Measure how strongly each individual feature separates placement status

from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder

print("Feature-level analysis:\n")

for column in numeric_features:
    auc = roc_auc_score(
        y,
        df[column]
    )
    
    # AUC below 0.5 can simply mean the relationship is reversed,
    # so use the distance from 0.5.
    strength = max(auc, 1 - auc)
    
    print(f"{column:30s} AUC = {auc:.4f} | strength = {strength:.4f}")
# Out:
# Feature-level analysis:
#
# age                            AUC = 0.5005 | strength = 0.5005
# cgpa                           AUC = 0.5064 | strength = 0.5064
# internships_count              AUC = 0.5334 | strength = 0.5334
# projects_count                 AUC = 0.5330 | strength = 0.5330
# certifications_count           AUC = 0.4977 | strength = 0.5023
# coding_skill_score             AUC = 0.5291 | strength = 0.5291
# aptitude_score                 AUC = 0.5182 | strength = 0.5182
# communication_skill_score      AUC = 0.5187 | strength = 0.5187
# logical_reasoning_score        AUC = 0.5206 | strength = 0.5206
# mock_interview_score           AUC = 0.5263 | strength = 0.5263
# backlogs                       AUC = 0.4614 | strength = 0.5386

# %% [markdown]
# ### Check whether placement status may have been generated

# %%
# Check whether placement status may have been generated
# from a simple threshold/rule.

print("Numeric feature ranges by placement status:\n")

for column in numeric_features:
    print(f"\n{column}")
    print(
        df.groupby("placement_status")[column]
        .agg(["min", "max", "mean", "std"])
        .round(3)
    )
# Out:
# Numeric feature ranges by placement status:
#
#
# age
#                   min  max    mean    std
# placement_status
# Not Placed         18   24  21.004  2.002
# Placed             18   24  21.007  1.997
#
# cgpa
#                   min   max   mean    std
# placement_status
# Not Placed        4.5  10.0  7.484  0.993
# Placed            4.5  10.0  7.508  0.992
#
# internships_count
#                   min  max   mean    std
# placement_status
# Not Placed          0    8  1.417  1.183
# Placed              0    8  1.573  1.255
#
# projects_count
#                   min  max   mean    std
# placement_status
# Not Placed          0   12  2.886  1.687
# Placed              0   13  3.098  1.762
#
# certifications_count
#                   min  max   mean    std
# placement_status
# Not Placed          0   10  2.011  1.416
# Placed              0   11  2.000  1.417
#
# coding_skill_score
#                    min    max    mean     std
# placement_status
# Not Placed        20.0  100.0  69.009  14.742
# Placed            20.0  100.0  70.508  14.620
#
# aptitude_score
#                    min    max    mean     std
# placement_status
# Not Placed        20.0  100.0  64.474  14.836
# Placed            20.0  100.0  65.418  14.837
#
# communication_skill_score
#                    min    max    mean     std
# placement_status
# Not Placed        20.0  100.0  67.473  13.819
# Placed            20.0  100.0  68.369  13.856
#
# logical_reasoning_score
#                    min    max    mean     std
# placement_status
# Not Placed        20.0  100.0  65.343  14.881
# Placed            20.0  100.0  66.424  14.763
#
# mock_interview_score
#                    min    max    mean     std
# placement_status
# Not Placed        20.0  100.0  69.388  11.932
# Placed            20.0  100.0  70.492  11.919
#
# backlogs
#                   min  max   mean    std
# placement_status
# Not Placed          0    6  0.561  0.752
# Placed              0    5  0.444  0.665

# %% [markdown]
# ### Inspect Logistic Regression coefficients

# %%
# Inspect Logistic Regression coefficients

feature_names = model.named_steps["preprocessor"].get_feature_names_out()
coefficients = model.named_steps["classifier"].coef_[0]

coef_df = (
    pd.DataFrame({
        "feature": feature_names,
        "coefficient": coefficients
    })
    .sort_values("coefficient", key=abs, ascending=False)
)

coef_df.head(20)
# Out:
#                            feature  coefficient
# 10                   num__backlogs    -0.172405
# 2           num__internships_count     0.128270
# 3              num__projects_count     0.126003
# 5          num__coding_skill_score     0.106529
# 9        num__mock_interview_score     0.094243
# 8     num__logical_reasoning_score     0.073678
# 6              num__aptitude_score     0.066440
# 7   num__communication_skill_score     0.062028
# 12                cat__gender_Male     0.048970
# 11              cat__gender_Female     0.042254
# 14               cat__branch_Civil     0.035732
# 21        cat__college_tier_Tier 3     0.035452
# 19        cat__college_tier_Tier 1     0.028561
# 20        cat__college_tier_Tier 2     0.027212
# 13                 cat__branch_CSE     0.026532
# 1                        num__cgpa     0.026525
# 18          cat__branch_Mechanical     0.024236
# 16                 cat__branch_EEE     0.017926
# 15                 cat__branch_ECE    -0.013225
# 4        num__certifications_count    -0.012653

# %%
print(df.columns.tolist())
# Out:
# ['age', 'gender', 'cgpa', 'branch', 'college_tier', 'internships_count', 'projects_count', 'certifications_count', 'coding_skill_score', 'aptitude_score', 'communication_skill_score', 'logical_reasoning_score', 'mock_interview_score', 'backlogs', 'placement_status', 'placement_status_numeric']

# %%
print(X.columns.tolist())
# Out:
# ['age', 'gender', 'cgpa', 'branch', 'college_tier', 'internships_count', 'projects_count', 'certifications_count', 'coding_skill_score', 'aptitude_score', 'communication_skill_score', 'logical_reasoning_score', 'mock_interview_score', 'backlogs']

# %%
print(y.name)
# Out:
# placement_status

# %%
print(y.value_counts())
# Out:
# placement_status
# 1    54459
# 0    45541
# Name: count, dtype: int64

# %%
print(y.value_counts(normalize=True) * 100)
# Out:
# placement_status
# 1    54.459
# 0    45.541
# Name: proportion, dtype: float64

# %%
print("Dataset shape:", df.shape)

print("\nDuplicate rows:", df.duplicated().sum())

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset shape: (100000, 16)
#
# Duplicate rows: 0
#
# Missing values:
# age                          0
# gender                       0
# cgpa                         0
# branch                       0
# college_tier                 0
# internships_count            0
# projects_count               0
# certifications_count         0
# coding_skill_score           0
# aptitude_score               0
# communication_skill_score    0
# logical_reasoning_score      0
# mock_interview_score         0
# backlogs                     0
# placement_status             0
# placement_status_numeric     0
# dtype: int64

# %%
rf_classifier = rf_model.named_steps["classifier"]

print(rf_classifier.feature_importances_)
# Out:
# [0.05210618 0.10993045 0.03428212 0.0472604  0.04856225 0.11411024
#  0.11361171 0.11335817 0.11426561 0.11442086 0.01771015 0.01125135
#  0.01133472 0.01318529 0.0085768  0.01009903 0.0088719  0.0115676
#  0.00891987 0.01128262 0.0131069  0.01218578]

# %%
import pandas as pd

# Get the trained preprocessor
preprocessor = rf_model.named_steps["preprocessor"]

# Get transformed feature names
feature_names = preprocessor.get_feature_names_out()

# Get Random Forest classifier
rf_classifier = rf_model.named_steps["classifier"]

# Create feature importance table
feature_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": rf_classifier.feature_importances_
})

# Sort from highest to lowest
feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

print(feature_importance)
# Out:
#                            Feature  Importance
# 9        num__mock_interview_score    0.114421
# 8     num__logical_reasoning_score    0.114266
# 5          num__coding_skill_score    0.114110
# 6              num__aptitude_score    0.113612
# 7   num__communication_skill_score    0.113358
# 1                        num__cgpa    0.109930
# 0                         num__age    0.052106
# 4        num__certifications_count    0.048562
# 3              num__projects_count    0.047260
# 2           num__internships_count    0.034282
# 10                   num__backlogs    0.017710
# 13                 cat__branch_CSE    0.013185
# 20        cat__college_tier_Tier 2    0.013107
# 21        cat__college_tier_Tier 3    0.012186
# 17                  cat__branch_IT    0.011568
# 12                cat__gender_Male    0.011335
# 19        cat__college_tier_Tier 1    0.011283
# 11              cat__gender_Female    0.011251
# 15                 cat__branch_ECE    0.010099
# 18          cat__branch_Mechanical    0.008920
# 16                 cat__branch_EEE    0.008872
# 14               cat__branch_Civil    0.008577

# %%
import matplotlib.pyplot as plt

# Sort importance from highest to lowest
top_features = feature_importance.sort_values(
    by="Importance",
    ascending=True
)

plt.figure(figsize=(10, 8))

plt.barh(
    top_features["Feature"],
    top_features["Importance"]
)

plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Random Forest Feature Importance")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(
    y_test,
    gb_pred,
    display_labels=["Not Placed", "Placed"]
)

plt.title("Gradient Boosting - Confusion Matrix")
plt.show()

# %% [markdown]
# ### ROC Curve

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Logistic Regression
RocCurveDisplay.from_predictions(
    y_test,
    y_prob,
    name="Logistic Regression"
)

# Random Forest
RocCurveDisplay.from_predictions(
    y_test,
    rf_prob,
    name="Random Forest"
)

# Gradient Boosting
RocCurveDisplay.from_predictions(
    y_test,
    gb_prob,
    name="Gradient Boosting"
)

plt.title("ROC Curve Comparison")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.show()

# %% [markdown]
# ### Check the target distribution

# %%
print(df["placement_status"].value_counts())

print(
    df["placement_status"]
    .value_counts(normalize=True) * 100
)
# Out:
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64
# placement_status
# Placed        54.459
# Not Placed    45.541
# Name: proportion, dtype: float64

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

dummy = DummyClassifier(strategy="most_frequent")

dummy.fit(X_train, y_train)

dummy_pred = dummy.predict(X_test)

print("Baseline Accuracy:",
      accuracy_score(y_test, dummy_pred))
# Out:
# Baseline Accuracy: 0.5446

# %% [markdown]
# ## Investigating Feature Distributions by Placement Status

# %%
import matplotlib.pyplot as plt

numerical_features = [
    "cgpa",
    "coding_skill_score",
    "aptitude_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "mock_interview_score"
]

for feature in numerical_features:

    plt.figure(figsize=(8, 4))

    for status in ["Placed", "Not Placed"]:

        plt.hist(
            df[df["placement_status"] == status][feature],
            bins=30,
            alpha=0.5,
            label=status
        )

    plt.title(f"{feature} Distribution by Placement Status")

    plt.xlabel(feature)
    plt.ylabel("Number of Students")

    plt.legend()

    plt.show()

# %% [markdown]
# # New Dataset Validation

# %%
import pandas as pd

df = pd.read_csv(
    "../data/student_placement_prediction_dataset_v2.csv"
)

backlog_placement = df.groupby(
    "backlogs",
    observed=True
)["placement_status"].apply(
    lambda x: (x == "Placed").mean()
)

print(backlog_placement)
# Out:
# backlogs
# 0    0.665801
# 1    0.629426
# 2    0.551857
# 3    0.584615
# 4    0.666667
# 5    0.500000
# Name: placement_status, dtype: float64

# %%
backlog_analysis = df.groupby(
    "backlogs",
    observed=True
)["placement_status"].agg(
    total_students="count",
    placed_students=lambda x: (x == "Placed").sum(),
    placement_rate=lambda x: (x == "Placed").mean()
)

print(backlog_analysis)
# Out:
#           total_students  placed_students  placement_rate
# backlogs
# 0                   6161             4102        0.665801
# 1                   2909             1831        0.629426
# 2                    781              431        0.551857
# 3                    130               76        0.584615
# 4                     15               10        0.666667
# 5                      4                2        0.500000

# %% [markdown]
# ### test CGPA + coding + interview together.

# %%
features_to_check = [
    "cgpa",
    "coding_skill_score",
    "communication_skill_score",
    "aptitude_score",
    "logical_reasoning_score",
    "mock_interview_score"
]

for feature in features_to_check:
    print(f"\n{feature}")
    result = df.groupby(
        pd.qcut(df[feature], 5, duplicates="drop"),
        observed=True
    )["placement_status"].apply(
        lambda x: (x == "Placed").mean()
    )
    print(result)
# Out:
# cgpa
# cgpa
# (4.999, 6.6]    0.540020
# (6.6, 7.25]     0.604125
# (7.25, 7.8]     0.650150
# (7.8, 8.45]     0.698198
# (8.45, 10.0]    0.734940
# Name: placement_status, dtype: float64
#
# coding_skill_score
# coding_skill_score
# (39.999, 55.0]    0.584203
# (55.0, 64.0]      0.618261
# (64.0, 72.0]      0.659656
# (72.0, 81.0]      0.665669
# (81.0, 95.0]      0.703603
# Name: placement_status, dtype: float64
#
# communication_skill_score
# communication_skill_score
# (39.999, 59.0]    0.614209
# (59.0, 66.0]      0.627672
# (66.0, 74.0]      0.652584
# (74.0, 82.0]      0.659927
# (82.0, 95.0]      0.675163
# Name: placement_status, dtype: float64
#
# aptitude_score
# aptitude_score
# (39.999, 57.0]    0.606573
# (57.0, 65.0]      0.631851
# (65.0, 73.0]      0.641827
# (73.0, 82.0]      0.664691
# (82.0, 95.0]      0.686510
# Name: placement_status, dtype: float64
#
# logical_reasoning_score
# logical_reasoning_score
# (39.999, 55.0]    0.603931
# (55.0, 64.0]      0.629208
# (64.0, 72.0]      0.638889
# (72.0, 81.0]      0.677899
# (81.0, 95.0]      0.678179
# Name: placement_status, dtype: float64
#
# mock_interview_score
# mock_interview_score
# (39.999, 53.0]    0.592243
# (53.0, 63.0]      0.616755
# (63.0, 71.0]      0.651712
# (71.0, 80.0]      0.656501
# (80.0, 95.0]      0.711675
# Name: placement_status, dtype: float64

# %% [markdown]
# ### Validate the categorical/count features

# %%
features_to_check = [
    "college_tier",
    "internships_count",
    "projects_count",
    "certifications_count",
    "branch"
]

for feature in features_to_check:
    print(f"\n{'=' * 50}")
    print(feature)
    print("=" * 50)

    result = df.groupby(
        feature,
        observed=True
    )["placement_status"].apply(
        lambda x: (x == "Placed").mean()
    )

    print(result)
# Out:
# ==================================================
# college_tier
# ==================================================
# college_tier
# 1    0.662490
# 2    0.648273
# 3    0.621785
# Name: placement_status, dtype: float64
#
# ==================================================
# internships_count
# ==================================================
# internships_count
# 0    0.631753
# 1    0.653129
# 2    0.642257
# 3    0.642778
# 4    0.706231
# Name: placement_status, dtype: float64
#
# ==================================================
# projects_count
# ==================================================
# projects_count
# 0    0.639655
# 1    0.637766
# 2    0.636822
# 3    0.643465
# 4    0.667857
# 5    0.663848
# 6    0.701107
# Name: placement_status, dtype: float64
#
# ==================================================
# certifications_count
# ==================================================
# certifications_count
# 0    0.631217
# 1    0.647748
# 2    0.647824
# 3    0.654825
# 4    0.631991
# 5    0.635593
# 6    0.645455
# 7    0.761905
# 8    0.500000
# Name: placement_status, dtype: float64
#
# ==================================================
# branch
# ==================================================
# branch
# CIVIL    0.669145
# CSE      0.634884
# ECE      0.647283
# EEE      0.648103
# IT       0.636599
# MECH     0.662979
# Name: placement_status, dtype: float64

# %% [markdown]
# ### One clean validation table

# %%
count_features = [
    "internships_count",
    "projects_count",
    "certifications_count"
]

for feature in count_features:
    print(f"\n{'=' * 60}")
    print(feature)
    print("=" * 60)

    result = df.groupby(
        feature,
        observed=True
    )["placement_status"].agg(
        students="count",
        placement_rate=lambda x: (x == "Placed").mean()
    )

    print(result)


print(f"\n{'=' * 60}")
print("BRANCH")
print("=" * 60)

branch_result = df.groupby(
    "branch",
    observed=True
)["placement_status"].agg(
    students="count",
    placement_rate=lambda x: (x == "Placed").mean()
)

print(branch_result)
# Out:
# ============================================================
# internships_count
# ============================================================
#                    students  placement_rate
# internships_count
# 0                      3017        0.631753
# 1                      3595        0.653129
# 2                      2144        0.642257
# 3                       907        0.642778
# 4                       337        0.706231
#
# ============================================================
# projects_count
# ============================================================
#                 students  placement_rate
# projects_count
# 0                   1160        0.639655
# 1                   2399        0.637766
# 2                   2580        0.636822
# 3                   1997        0.643465
# 4                   1120        0.667857
# 5                    473        0.663848
# 6                    271        0.701107
#
# ============================================================
# certifications_count
# ============================================================
#                       students  placement_rate
# certifications_count
# 0                         1307        0.631217
# 1                         2731        0.647748
# 2                         2689        0.647824
# 3                         1886        0.654825
# 4                          894        0.631991
# 5                          354        0.635593
# 6                          110        0.645455
# 7                           21        0.761905
# 8                            8        0.500000
#
# ============================================================
# BRANCH
# ============================================================
#         students  placement_rate
# branch
# CIVIL        807        0.669145
# CSE         3010        0.634884
# ECE         1840        0.647283
# EEE         1239        0.648103
# IT          1929        0.636599
# MECH        1175        0.662979

# %% [markdown]
# ### Final categorical check

# %%
print("CERTIFICATIONS")
print("=" * 50)

cert_result = df.groupby(
    "certifications_count",
    observed=True
)["placement_status"].agg(
    students="count",
    placement_rate=lambda x: (x == "Placed").mean()
)

print(cert_result)


print("\nBRANCH")
print("=" * 50)

branch_result = df.groupby(
    "branch",
    observed=True
)["placement_status"].agg(
    students="count",
    placement_rate=lambda x: (x == "Placed").mean()
)

print(branch_result)
# Out:
# CERTIFICATIONS
# ==================================================
#                       students  placement_rate
# certifications_count
# 0                         1307        0.631217
# 1                         2731        0.647748
# 2                         2689        0.647824
# 3                         1886        0.654825
# 4                          894        0.631991
# 5                          354        0.635593
# 6                          110        0.645455
# 7                           21        0.761905
# 8                            8        0.500000
#
# BRANCH
# ==================================================
#         students  placement_rate
# branch
# CIVIL        807        0.669145
# CSE         3010        0.634884
# ECE         1840        0.647283
# EEE         1239        0.648103
# IT          1929        0.636599
# MECH        1175        0.662979

# %%
# Final statistical validation

numeric_features = [
    "age",
    "cgpa",
    "college_tier",
    "internships_count",
    "projects_count",
    "certifications_count",
    "coding_skill_score",
    "communication_skill_score",
    "aptitude_score",
    "logical_reasoning_score",
    "mock_interview_score",
    "backlogs"
]

validation_df = df.copy()

validation_df["placement_numeric"] = (
    validation_df["placement_status"] == "Placed"
).astype(int)

correlations = validation_df[
    numeric_features + ["placement_numeric"]
].corr(method="spearman")["placement_numeric"].drop(
    "placement_numeric"
).sort_values(ascending=False)

print("Spearman correlation with placement:")
print(correlations)
# Out:
# Spearman correlation with placement:
# cgpa                         0.146514
# coding_skill_score           0.086199
# mock_interview_score         0.081872
# aptitude_score               0.058093
# logical_reasoning_score      0.057852
# communication_skill_score    0.051916
# projects_count               0.020601
# internships_count            0.015857
# age                          0.005022
# certifications_count         0.004239
# college_tier                -0.029982
# backlogs                    -0.061300
# Name: placement_numeric, dtype: float64
